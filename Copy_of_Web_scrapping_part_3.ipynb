# %% [markdown]
# <a href="https://colab.research.google.com/github/mayank-liv/Coursera_Capstone/blob/master/Copy_of_Web_scrapping_part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The First Part of assignment**
#
# (I have skipped explaining the first and second part of the assingment in this notebook, only explaining the third part which this notebook is all about)

# %%
import folium

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np

# %%
site = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(site, 'lxml')

#print(soup.prettify())

table= soup.find('table', class_='wikitable sortable')

rows_table = table.find_all('tr')

#print(rows_table)

list = []

for tr in rows_table:
    td=tr.find_all('td')
    row_txt= [pr.text for pr in td]
    list.append(row_txt)

# %%
df = pd.DataFrame(list, columns=['PostalCode', 'Borough', 'Neighborhood'])[1:]

df = df[df['Borough'] != 'Not assigned']

df.head()
# Out:
#   PostalCode           Borough        Neighborhood
# 3        M3A        North York         Parkwoods\n
# 4        M4A        North York  Victoria Village\n
# 5        M5A  Downtown Toronto      Harbourfront\n
# 6        M5A  Downtown Toronto       Regent Park\n
# 7        M6A        North York  Lawrence Heights\n

# %%
same_pcode = df["PostalCode"].duplicated(keep= False)

df1 = df[-same_pcode]

print(df1.head())

df2 = df[same_pcode]

print(df2.head())
# Out:
#    PostalCode       Borough        Neighborhood
# 3         M3A    North York         Parkwoods\n
# 4         M4A    North York  Victoria Village\n
# 9         M7A  Queen's Park      Not assigned\n
# 11        M9A     Etobicoke  Islington Avenue\n
# 15        M3B    North York   Don Mills North\n
#    PostalCode           Borough        Neighborhood
# 5         M5A  Downtown Toronto      Harbourfront\n
# 6         M5A  Downtown Toronto       Regent Park\n
# 7         M6A        North York  Lawrence Heights\n
# 8         M6A        North York    Lawrence Manor\n
# 12        M1B       Scarborough             Rouge\n

# %%
bool1= df2.duplicated('PostalCode', keep='last')
df3= df2[bool1]
df4 = df2[-bool1]
bool2 = df3.duplicated('PostalCode', keep='last')
df5 = df3[bool2]
df6 = df3[-bool2]
#print(df4)
#print(df5)
bool3 = df5.duplicated('PostalCode', keep='last')
df7= df5[bool3]
df8 = df5[-bool3]
bool4= df7.duplicated('PostalCode', keep='last')
df9 = df7[bool4]
df10 = df7[-bool4]
bool5= df9.duplicated('PostalCode', keep='last')
df11 = df9[bool5]
df12 = df9[-bool5]
bool6= df11.duplicated('PostalCode', keep='last')
df13 = df11[bool6]
df14 = df11[-bool6]
bool7= df13.duplicated('PostalCode', keep='last')
df15 = df13[bool7]
df16 = df13[-bool7]
bool8= df15.duplicated('PostalCode', keep='last')
df17 = df15[bool8]
df18 = df15[-bool8]
final1 = pd.merge(df18, df16, on= ['PostalCode', 'Borough'],how='outer')
final2 = pd.merge(final1, df16, on= ['PostalCode', 'Borough'],how='outer')
final3 = pd.merge(final2, df14, on= ['PostalCode', 'Borough'],how='outer')
final4=  pd.merge(final3, df12, on= ['PostalCode', 'Borough'],how='outer')
final5=  pd.merge(final4, df10, on= ['PostalCode', 'Borough'],how='outer')
final6=  pd.merge(final5, df8, on= ['PostalCode', 'Borough'],how='outer')
final7=  pd.merge(final6, df6, on= ['PostalCode', 'Borough'],how='outer')
final8=  pd.merge(final7, df4, on= ['PostalCode', 'Borough'],how='outer')
final9=  pd.merge(final8, df1, on= ['PostalCode', 'Borough'],how='outer')
final9 = final9.replace(np.nan, '', regex=True)
columnNumbers = [x for x in range(final9.shape[1])]  

columnNumbers.remove(4) #removing column integer index 0
final9 = final9.iloc[:, columnNumbers]

final9
# Out:
#     PostalCode  ...                                     Neighborhood_y
# 0          M9V  ...
# 1          M8Y  ...
# 2          M5V  ...
# 3          M9B  ...
# 4          M4V  ...
# 5          M8Z  ...
# 6          M9C  ...
# 7          M6M  ...
# 8          M9R  ...
# 9          M1V  ...
# 10         M1C  ...
# 11         M1E  ...
# 12         M3H  ...
# 13         M5H  ...
# 14         M2J  ...
# 15         M5J  ...
# 16         M1K  ...
# 17         M6K  ...
# 18         M1L  ...
# 19         M6L  ...
# 20         M1M  ...
# 21         M1P  ...
# 22         M5R  ...
# 23         M1T  ...
# 24         M5T  ...
# 25         M8V  ...
# 26         M8X  ...
# 27         M5A  ...
# 28         M6A  ...
# 29         M1B  ...
# ..         ...  ...                                                ...
# 73         M1H  ...                                        Cedarbrae\n
# 74         M2H  ...                                Hillcrest Village\n
# 75         M4H  ...                                 Thorncliffe Park\n
# 76         M1J  ...                              Scarborough Village\n
# 77         M4J  ...                                     East Toronto\n
# 78         M2K  ...                                  Bayview Village\n
# 79         M3L  ...                                   Downsview West\n
# 80         M9L  ...                                    Humber Summit\n
# 81         M3M  ...                                Downsview Central\n
# 82         M4M  ...                                  Studio District\n
# 83         M2N  ...                                 Willowdale South\n
# 84         M3N  ...                              Downsview Northwest\n
# 85         M4N  ...                                    Lawrence Park\n
# 86         M5N  ...                                         Roselawn\n
# 87         M9N  ...                                           Weston\n
# 88         M2P  ...                                  York Mills West\n
# 89         M4P  ...                                 Davisville North\n
# 90         M9P  ...                                        Westmount\n
# 91         M2R  ...                                  Willowdale West\n
# 92         M4R  ...                               North Toronto West\n
# 93         M7R  ...            Canada Post Gateway Processing Centre\n
# 94         M1S  ...                                        Agincourt\n
# 95         M4S  ...                                       Davisville\n
# 96         M1W  ...                                  L'Amoreaux West\n
# 97         M4W  ...                                         Rosedale\n
# 98         M5W  ...                  Stn A PO Boxes 25 The Esplanade\n
# 99         M9W  ...                                        Northwest\n
# 100        M1X  ...                                      Upper Rouge\n
# 101        M4Y  ...                             Church and Wellesley\n
# 102        M7Y  ...  Business Reply Mail Processing Centre 969 East...
#
# [103 rows x 11 columns]

# %%
final9.columns =['PostalCode', 'Borough', 'Neighborhood_a', 'Neighborhood_b',
       'Neighborhood_c', 'Neighborhood_d', 'Neighborhood_e', 'Neighborhood_f',
       'Neighborhood_g', 'Neighborhood_h', 'Neighborhood_i']

final9['combined']=final9['Neighborhood_i']+','+final9['Neighborhood_h']+','+final9['Neighborhood_g']+','+final9['Neighborhood_f']+','+final9['Neighborhood_e']+','+final9['Neighborhood_d']+','+final9['Neighborhood_c']+','+final9['Neighborhood_b']+','+final9['Neighborhood_a']

final9= final9.loc[:,['PostalCode', 'Borough', 'combined']]
final9.columns=['PostalCode', 'Borough', 'Neighborhood']
final9.head()
# Out:
#   PostalCode  ...                                       Neighborhood
# 0        M9V  ...  ,Thistletown\n,South Steeles\n,Silverstone\n,M...
# 1        M8Y  ...  ,Sunnylea\n,Royal York South East\n,The Queens...
# 2        M5V  ...  ,South Niagara\n,Railway Lands\n,King and Spad...
# 3        M9B  ...  ,West Deane Park\n,Princess Gardens\n,Martin G...
# 4        M4V  ...  ,Summerhill West\n,South Hill\n,Rathnelly\n,Fo...
#
# [5 rows x 3 columns]

# %%
def clean_df(x):
    x=x.replace("\n","").replace(",,,,","").replace(",,,","").replace(",,","")
    return x
final9['Neighborhood']= final9['Neighborhood'].apply(clean_df)
final9.head()
# Out:
#   PostalCode  ...                                       Neighborhood
# 0        M9V  ...  ,Thistletown,South Steeles,Silverstone,Mount O...
# 1        M8Y  ...  ,Sunnylea,Royal York South East,The Queensway ...
# 2        M5V  ...  ,South Niagara,Railway Lands,King and Spadina,...
# 3        M9B  ...  ,West Deane Park,Princess Gardens,Martin Grove...
# 4        M4V  ...  ,Summerhill West,South Hill,Rathnelly,Forest H...
#
# [5 rows x 3 columns]

# %%
final9.shape
# Out:
# (103, 3)

# %% [markdown]
# **The second part of the assignment**

# %%
Lat_file= pd.read_csv("Geospatial_Coordinates.csv")
Lat_file.columns=['PostalCode', 'Latitude', 'Longitude']

final10= pd.merge(final9, Lat_file, on=['PostalCode'])

final10.head()
# Out:
#   PostalCode           Borough  ...   Latitude  Longitude
# 0        M9V         Etobicoke  ...  43.739416 -79.588437
# 1        M8Y         Etobicoke  ...  43.636258 -79.498509
# 2        M5V  Downtown Toronto  ...  43.628947 -79.394420
# 3        M9B         Etobicoke  ...  43.650943 -79.554724
# 4        M4V   Central Toronto  ...  43.686412 -79.400049
#
# [5 rows x 5 columns]

# %%
final10
# Out:
#     PostalCode           Borough  ...   Latitude  Longitude
# 0          M9V         Etobicoke  ...  43.739416 -79.588437
# 1          M8Y         Etobicoke  ...  43.636258 -79.498509
# 2          M5V  Downtown Toronto  ...  43.628947 -79.394420
# 3          M9B         Etobicoke  ...  43.650943 -79.554724
# 4          M4V   Central Toronto  ...  43.686412 -79.400049
# 5          M8Z         Etobicoke  ...  43.628841 -79.520999
# 6          M9C         Etobicoke  ...  43.643515 -79.577201
# 7          M6M              York  ...  43.691116 -79.476013
# 8          M9R         Etobicoke  ...  43.688905 -79.554724
# 9          M1V       Scarborough  ...  43.815252 -79.284577
# 10         M1C       Scarborough  ...  43.784535 -79.160497
# 11         M1E       Scarborough  ...  43.763573 -79.188711
# 12         M3H        North York  ...  43.754328 -79.442259
# 13         M5H  Downtown Toronto  ...  43.650571 -79.384568
# 14         M2J        North York  ...  43.778517 -79.346556
# 15         M5J  Downtown Toronto  ...  43.640816 -79.381752
# 16         M1K       Scarborough  ...  43.727929 -79.262029
# 17         M6K      West Toronto  ...  43.636847 -79.428191
# 18         M1L       Scarborough  ...  43.711112 -79.284577
# 19         M6L        North York  ...  43.713756 -79.490074
# 20         M1M       Scarborough  ...  43.716316 -79.239476
# 21         M1P       Scarborough  ...  43.757410 -79.273304
# 22         M5R   Central Toronto  ...  43.672710 -79.405678
# 23         M1T       Scarborough  ...  43.781638 -79.304302
# 24         M5T  Downtown Toronto  ...  43.653206 -79.400049
# 25         M8V         Etobicoke  ...  43.605647 -79.501321
# 26         M8X         Etobicoke  ...  43.653654 -79.506944
# 27         M5A  Downtown Toronto  ...  43.654260 -79.360636
# 28         M6A        North York  ...  43.718518 -79.464763
# 29         M1B       Scarborough  ...  43.806686 -79.194353
# ..         ...               ...  ...        ...        ...
# 73         M1H       Scarborough  ...  43.773136 -79.239476
# 74         M2H        North York  ...  43.803762 -79.363452
# 75         M4H         East York  ...  43.705369 -79.349372
# 76         M1J       Scarborough  ...  43.744734 -79.239476
# 77         M4J         East York  ...  43.685347 -79.338106
# 78         M2K        North York  ...  43.786947 -79.385975
# 79         M3L        North York  ...  43.739015 -79.506944
# 80         M9L        North York  ...  43.756303 -79.565963
# 81         M3M        North York  ...  43.728496 -79.495697
# 82         M4M      East Toronto  ...  43.659526 -79.340923
# 83         M2N        North York  ...  43.770120 -79.408493
# 84         M3N        North York  ...  43.761631 -79.520999
# 85         M4N   Central Toronto  ...  43.728020 -79.388790
# 86         M5N   Central Toronto  ...  43.711695 -79.416936
# 87         M9N              York  ...  43.706876 -79.518188
# 88         M2P        North York  ...  43.752758 -79.400049
# 89         M4P   Central Toronto  ...  43.712751 -79.390197
# 90         M9P         Etobicoke  ...  43.696319 -79.532242
# 91         M2R        North York  ...  43.782736 -79.442259
# 92         M4R   Central Toronto  ...  43.715383 -79.405678
# 93         M7R       Mississauga  ...  43.636966 -79.615819
# 94         M1S       Scarborough  ...  43.794200 -79.262029
# 95         M4S   Central Toronto  ...  43.704324 -79.388790
# 96         M1W       Scarborough  ...  43.799525 -79.318389
# 97         M4W  Downtown Toronto  ...  43.679563 -79.377529
# 98         M5W  Downtown Toronto  ...  43.646435 -79.374846
# 99         M9W         Etobicoke  ...  43.706748 -79.594054
# 100        M1X       Scarborough  ...  43.836125 -79.205636
# 101        M4Y  Downtown Toronto  ...  43.665860 -79.383160
# 102        M7Y      East Toronto  ...  43.662744 -79.321558
#
# [103 rows x 5 columns]

# %% [markdown]
# **THE THIRD PART OF THE ASSIGNMENT**
#
# We first initialise our Foursquare API ID details

# %%
VERSION = VERSION = '20180605'

LIMIT = 100

RADIUS = 500

# %% [markdown]
# First, we change our dataframe to include only the boroughs that include the word 'Toronto' in them

# %%
boolean = [ True if "Toronto" in dummy else False for dummy in final10['Borough']]

final11 = final10[boolean]

final11.head()
# Out:
#    PostalCode           Borough  ...   Latitude  Longitude
# 2         M5V  Downtown Toronto  ...  43.628947 -79.394420
# 4         M4V   Central Toronto  ...  43.686412 -79.400049
# 13        M5H  Downtown Toronto  ...  43.650571 -79.384568
# 15        M5J  Downtown Toronto  ...  43.640816 -79.381752
# 17        M6K      West Toronto  ...  43.636847 -79.428191
#
# [5 rows x 5 columns]

# %% [markdown]
# We make a function to get the closest venues to our boroughs

# %%
def nearby_places(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
                  
        url ='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            50, 
            100)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhoods centre Latitude', 
                  'Neighborhoods centre Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

Toronto_info = nearby_places(names=final11['Neighborhood'],
                                   latitudes=final11['Latitude'],
                                   longitudes=final11['Longitude']
                                  )

Toronto_info.head()
# Out:
#                                         Neighborhood  ...         Venue Category
# 0  ,South Niagara,Railway Lands,King and Spadina,...  ...  Performing Arts Venue
# 1                           ,Richmond,King,Adelaide,  ...       Greek Restaurant
# 2                           ,Richmond,King,Adelaide,  ...    Japanese Restaurant
# 3          ,Kensington Market,Grange Park,Chinatown,  ...                   Café
# 4          ,Kensington Market,Grange Park,Chinatown,  ...           Cocktail Bar
#
# [5 rows x 7 columns]

# %% [markdown]
# Now, we check how many unique venues are there

# %%
print("Number of unique venues are :" + str(len(Toronto_info['Venue Category'].unique())))
# Out:
# Number of unique venues are :24

# %% [markdown]
# We convert categorical data into numbers, using pd.getdummies

# %%
Toronto_x = pd.get_dummies(Toronto_info[['Venue Category']], prefix="", prefix_sep="")

Toronto_x['Neighborhood'] = Toronto_info['Neighborhood'] 


Toronto_x.head()
# Out:
#    Art Gallery  ...                                       Neighborhood
# 0            0  ...  ,South Niagara,Railway Lands,King and Spadina,...
# 1            0  ...                           ,Richmond,King,Adelaide,
# 2            0  ...                           ,Richmond,King,Adelaide,
# 3            0  ...          ,Kensington Market,Grange Park,Chinatown,
# 4            0  ...          ,Kensington Market,Grange Park,Chinatown,
#
# [5 rows x 25 columns]

# %%
Toronto_grouped = Toronto_x.groupby('Neighborhood').mean().reset_index()
Toronto_grouped.shape
# Out:
# (11, 25)

# %% [markdown]
# We try and print the most common venues around our neighbourhoods

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 8

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                          Neighborhood  ... 8th Most Common Venue
# 0           ,Kensington Market,Grange Park,Chinatown,  ...             Bookstore
# 1                            ,Richmond,King,Adelaide,  ...          Cocktail Bar
# 2   ,South Niagara,Railway Lands,King and Spadina,...  ...          Cocktail Bar
# 3            ,Toronto Dominion Centre,Design Exchange  ...             Bookstore
# 4                            ,Trinity,Little Portugal  ...          Cocktail Bar
# 5              ,Underground city,First Canadian Place  ...        Breakfast Spot
# 6                      ,Victoria Hotel,Commerce Court  ...        Breakfast Spot
# 7                                            Christie  ...          Cocktail Bar
# 8                                          Davisville  ...             Bookstore
# 9                                      St. James Town  ...                  Café
# 10                    Stn A PO Boxes 25 The Esplanade  ...                  Café
#
# [11 rows x 9 columns]

# %% [markdown]
# Now I perform K-Means clustering on the above data

# %%
from sklearn.cluster import KMeans

kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)


kmeans.labels_[0:10]
Toronto_grouped= pd.merge(final11,Toronto_grouped, on='Neighborhood', how='right')

# %%
Toronto_merged = Toronto_grouped
Toronto_merged['Cluster Labels'] = kmeans.labels_

Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood', how='left')
Toronto_merged.head()
# Out:
#   PostalCode           Borough  ... 7th Most Common Venue  8th Most Common Venue
# 0        M5V  Downtown Toronto  ...                  Café           Cocktail Bar
# 1        M5H  Downtown Toronto  ...                  Café           Cocktail Bar
# 2        M5T  Downtown Toronto  ...                Bakery              Bookstore
# 3        M6J      West Toronto  ...                  Café           Cocktail Bar
# 4        M5K  Downtown Toronto  ...                Bakery              Bookstore
#
# [5 rows x 38 columns]

# %% [markdown]
# Finally, we print the map acoording to the data we found

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
map_clusters = folium.Map(location=[43.6532, -79.3832], zoom_start=11)


x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]


markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
